# %%
# import header files
# %matplotlib inline
import torch
import torch.nn as nn
import torchvision
from functools import partial
from dataclasses import dataclass
from collections import OrderedDict
import glob
import os
import random
import tensorflow as tf
from tensorflow import keras
import numpy as np
import seaborn as sn
import pandas as pd
from matplotlib import pyplot as plt
from tqdm import tqdm
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support
import time
import copy
import tqdm
import torch
import random
from PIL import Image
import torch.optim as optim
from torchvision import models
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.utils.data import TensorDataset,DataLoader

# %%
# load my google drive
def auth_gdrive():
  from google.colab import drive
  if os.path.exists('content/gdrive/My Drive'): return
  drive.mount('/content/gdrive')
def load_gdrive_dataset():
  loader_assets = 'OurALL_IDB2.zip'
  auth_gdrive()

# %%
# mount my google drive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
load_gdrive_dataset()
# Out:
# Mounted at /content/gdrive
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# unzip ALL_IDB2 dataset
# !unzip "/content/gdrive/MyDrive/OurALL-IDB2.zip"
# Out:
# Archive:  /content/gdrive/MyDrive/OurALL-IDB2.zip
#    creating: OurALL-IDB2/
#    creating: OurALL-IDB2/content/
#    creating: OurALL-IDB2/content/dataset/
#    creating: OurALL-IDB2/content/dataset/test/
#    creating: OurALL-IDB2/content/dataset/test/blast/
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im027_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im028_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im029_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im030_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im031_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im032_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im033_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im034_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im035_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im036_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im037_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im038_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im039_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im040_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im041_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im042_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im043_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im044_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im045_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im046_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im047_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im048_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im049_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im050_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im051_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im052_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im053_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im054_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im055_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im056_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im057_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im058_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im059_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im060_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im061_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im062_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im063_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im064_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im065_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im066_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im067_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im068_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im069_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im070_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im071_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im072_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im073_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im074_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im075_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im076_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im077_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im078_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im079_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im080_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im081_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im082_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im083_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im084_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im085_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im086_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im087_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im088_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im089_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im090_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im091_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im092_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im093_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im094_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im095_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im096_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im097_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im098_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im099_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im100_1.tif
#   inflating: OurALL-IDB2/content/dataset/test/blast/Im101_1.tif
#    creating: OurALL-IDB2/content/dataset/test/healthy/
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im157_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im158_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im159_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im160_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im161_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im162_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im163_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im164_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im165_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im166_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im167_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im168_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im169_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im170_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im171_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im172_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im173_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im174_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im175_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im176_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im177_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im178_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im179_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im180_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im181_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im182_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im183_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im184_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im185_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im186_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im187_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im188_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im189_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im190_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im191_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im192_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im193_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im194_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im195_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im196_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im197_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im198_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im199_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im200_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im201_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im202_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im203_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im204_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im205_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im206_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im207_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im208_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im209_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im210_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im211_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im212_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im213_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im214_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im215_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im216_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im217_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im218_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im219_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im220_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im221_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im222_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im223_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im224_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im225_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im226_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im227_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im228_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im229_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im230_0.tif
#   inflating: OurALL-IDB2/content/dataset/test/healthy/Im231_0.tif
#    creating: OurALL-IDB2/content/dataset/train/
#    creating: OurALL-IDB2/content/dataset/train/blast/
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_100_1544124.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_100_3149220.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_100_474672.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_101_1486895.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_101_3380230.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_101_371885.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_102_4050461.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_102_9333559.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_102_9955881.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_103_2507602.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_103_3983733.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_103_5919446.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_104_3730105.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_104_3845679.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_104_7378153.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_105_3202442.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_105_6012898.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_105_6120329.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_106_2577122.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_106_293020.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_106_4492370.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_107_1177572.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_107_3722467.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_107_9425690.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug_108_5696114.tif
#   inflating: OurALL-IDB2/content/dataset/train/blast/aug
0.tif
#   inflating: OurALL-IDB2/content/dataset/train/healthy/Im246_0.tif
#   inflating: OurALL-IDB2/content/dataset/train/healthy/Im247_0.tif
#   inflating: OurALL-IDB2/content/dataset/train/healthy/Im248_0.tif
#   inflating: OurALL-IDB2/content/dataset/train/healthy/Im249_0.tif
#   inflating: OurALL-IDB2/content/dataset/train/healthy/Im250_0.tif
#   inflating: OurALL-IDB2/content/dataset/train/healthy/Im251_0.tif
#   inflating: OurALL-IDB2/content/dataset/train/healthy/Im252_0.tif
#   inflating: OurALL-IDB2/content/dataset/train/healthy/Im253_0.tif
#   inflating: OurALL-IDB2/content/dataset/train/healthy/Im254_0.tif
#   inflating: OurALL-IDB2/content/dataset/train/healthy/Im255_0.tif
#   inflating: OurALL-IDB2/content/dataset/train/healthy/Im256_0.tif
#   inflating: OurALL-IDB2/content/dataset/train/healthy/Im257_0.tif
#   inflating: OurALL-IDB2/content/dataset/train/healthy/Im258_0.tif
#   inflating: OurALL-IDB2/content/dataset/train/healthy/Im259_0.tif
#   inflating: OurALL-IDB2/content/dataset/train/healthy/Im260_0.tif
#    creating: OurALL-IDB2/content/dataset/validation/
#    creating: OurALL-IDB2/content/dataset/validation/blast/
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_0_2680992.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_0_5104392.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_0_5363511.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_1_1241205.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_1_8006588.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_1_8053249.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_2_7786006.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_2_8056831.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_2_8803483.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_3_2564962.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_3_8541155.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_3_971873.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_4_514995.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_4_5190289.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_4_5723138.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_5_1582430.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_5_8034284.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_5_8619336.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_6_2927049.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_6_3645441.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_6_7939110.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_7_3617054.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_7_5107834.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_7_8911555.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/aug_8_776957.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im001_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im003_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im004_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im005_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im006_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im007_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im008_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im009_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im010_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im011_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im012_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im013_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im014_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im015_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im016_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im017_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im018_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im019_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im020_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im021_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im022_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im023_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im024_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im025_1.tif
#   inflating: OurALL-IDB2/content/dataset/validation/blast/Im026_1.tif
#    creating: OurALL-IDB2/content/dataset/validation/healthy/
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_0_3725580.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_0_4180205.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_0_524719.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_1_3927139.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_1_7613102.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_1_9303557.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_2_5256966.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_2_5666820.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_2_821090.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_3_2125570.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_3_4175240.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_3_7744963.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_4_2353802.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_4_2421041.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_4_2424917.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_5_1753710.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_5_9310606.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_5_9422024.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_6_4014672.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_6_4301102.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_6_4890893.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_7_1359298.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_7_3585158.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_7_6883774.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/aug_8_2611053.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im131_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im132_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im133_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im134_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im135_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im136_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im138_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im139_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im140_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im141_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im142_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im143_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im144_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im145_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im146_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im147_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im148_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im149_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im150_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im151_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im152_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im153_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im154_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im155_0.tif
#   inflating: OurALL-IDB2/content/dataset/validation/healthy/Im156_0.tif

# %%
# Count the number of samples in the training set, validation set and test set
trainingset_healthy = os.listdir("/content/OurALL-IDB2/content/dataset/train/healthy/")
trainingset_blast = os.listdir("/content/OurALL-IDB2/content/dataset/train/blast/")
number_trainingset = len(trainingset_healthy+trainingset_blast)
print("The number of samples in the training set is:", number_trainingset)
validationset_healthy = os.listdir("/content/OurALL-IDB2/content/dataset/validation/healthy/")
validationset_blast = os.listdir("/content/OurALL-IDB2/content/dataset/validation/blast/")
number_validationset = len(validationset_healthy+validationset_blast)
print("The number of samples in the validation set is:", number_validationset)
testset_healthy = os.listdir("/content/OurALL-IDB2/content/dataset/test/healthy/")
testset_blast = os.listdir("/content/OurALL-IDB2/content/dataset/test/blast/")
number_testset = len(testset_healthy+testset_blast)
print("The number of samples in the test set is:", number_testset)
# Out:
# The number of samples in the training set is: 750
# The number of samples in the validation set is: 100
# The number of samples in the test set is: 150

# %%
# define transforms
train_transforms = torchvision.transforms.Compose([torchvision.transforms.RandomRotation(30),
                                       torchvision.transforms.Resize((256, 256)),
                                       torchvision.transforms.RandomHorizontalFlip(),
                                       torchvision.transforms.ToTensor(),
                                       torchvision.transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

# %%
# get data
train_data = torchvision.datasets.ImageFolder("/content/OurALL-IDB2/content/dataset/train/", transform=train_transforms)
train_data = torchvision.datasets.ImageFolder("/content/OurALL-IDB2/content/dataset/validation/", transform=train_transforms)
test_data = torchvision.datasets.ImageFolder("/content/OurALL-IDB2/content/dataset/test/", transform=train_transforms)

# %%
# data loader
trainloader = torch.utils.data.DataLoader(train_data, batch_size=8, shuffle=True, num_workers=1, pin_memory=True)
testloader = torch.utils.data.DataLoader(test_data, batch_size=8, shuffle=True, num_workers=1, pin_memory=True)
# Create a list of our detection classes
classes = ["healty", "blast"]
# plot random a batch images
from torchvision.utils import make_grid
def show_batch(dl, classes):
  for data, labels in dl:
    fig, ax = plt.subplots(figsize=(32, 16))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(data[:32], nrow=8).squeeze().permute(1, 2, 0).clamp(0,1))
    print('Labels: ', list(map(lambda l: classes[l], labels)))
    break
show_batch(trainloader, classes)
# Out:
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Labels:  ['healty', 'healty', 'blast', 'healty', 'healty', 'healty', 'healty', 'healty']

# %%
# define PVDAB

class ChannelAttention(nn.Module):
    def __init__(self, in_planes, ratio=16):
        super(ChannelAttention, self).__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)

        self.fc1   = nn.Conv2d(in_planes, in_planes // 16, 1, bias=False)
        self.relu1 = nn.ReLU()
        self.fc2   = nn.Conv2d(in_planes // 16, in_planes, 1, bias=False)

        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg_out = self.fc2(self.relu1(self.fc1(self.avg_pool(x))))
        max_out = self.fc2(self.relu1(self.fc1(self.max_pool(x))))
        out = avg_out + max_out
        return self.sigmoid(out)

class SpatialAttention(nn.Module):
    def __init__(self, kernel_size=3):
        super(SpatialAttention, self).__init__()

        assert kernel_size in (3, 7), 'kernel size must be 3 or 7'
        padding = 3 if kernel_size == 7 else 1

        self.conv1 = nn.Conv2d(2, 1, kernel_size, padding=padding, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        x = torch.cat([avg_out, max_out], dim=1)
        x = self.conv1(x)
        return self.sigmoid(x)

class PVDAB(nn.Module):
    def __init__(self, in_planes):
        super(PVDAB, self).__init__()

        self.ca = ChannelAttention(in_planes)
        self.sa = SpatialAttention()

    def forward(self, x):

        out = x * (self.ca(x))
        out = out * (self.sa(out))

        return out

# %%
# define the model
class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

        self.pvdab = PVDAB(planes)

    def forward(self, x):
        residual = x
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out = self.pvdab(out)
        out += self.shortcut(residual)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):
    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion*planes, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion*planes)
        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

        self.pvdab = PVDAB(self.expansion*planes)

    def forward(self, x):
        residual = x
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out = self.pvdab(out)
        out += self.shortcut(residual)
        out = F.relu(out)
        return out


class ResNetPVDAB(nn.Module):
    def __init__(self, block, num_blocks, num_classes=2):
        super(ResNetPVDAB, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(32768*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18PVDAB():
    return ResNetPVDAB(BasicBlock, [2,2,2,2])

def ResNet34PVDAB():
    return ResNetPVDAB(BasicBlock, [3,4,6,3])

def ResNet50PVDAB():
    return ResNetPVDAB(Bottleneck, [3,4,6,3])

def ResNet101PVDAB():
    return ResNetPVDAB(Bottleneck, [3,4,23,3])

def ResNet152PVDAB():
    return ResNetPVDAB(Bottleneck, [3,8,36,3])

# %%
# print the model architecture
import math
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ResNet18PVDAB()
model.to(device)
# Out:
# ResNetPVDAB(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (pvdab): PVDAB(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (pvdab): PVDAB(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(64, 4, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(4, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (pvdab): PVDAB(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (pvdab): PVDAB(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(128, 8, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(8, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (pvdab): PVDAB(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (pvdab): PVDAB(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(16, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (pvdab): PVDAB(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#       (pvdab): PVDAB(
#         (ca): ChannelAttention(
#           (avg_pool): AdaptiveAvgPool2d(output_size=1)
#           (max_pool): AdaptiveMaxPool2d(output_size=1)
#           (fc1): Conv2d(512, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (relu1): ReLU()
#           (fc2): Conv2d(32, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#         (sa): SpatialAttention(
#           (conv1): Conv2d(2, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (sigmoid): Sigmoid()
#         )
#       )
#     )
#   )
#   (linear): Linear(in_features=32768, out_features=2, bias=True)
# )

# %%
# print summary of the model
from torchvision import models
from torchsummary import summary
summary(model, (3, 256, 256))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 256, 256]           1,728
#        BatchNorm2d-2         [-1, 64, 256, 256]             128
#             Conv2d-3         [-1, 64, 256, 256]          36,864
#        BatchNorm2d-4         [-1, 64, 256, 256]             128
#             Conv2d-5         [-1, 64, 256, 256]          36,864
#        BatchNorm2d-6         [-1, 64, 256, 256]             128
#  AdaptiveAvgPool2d-7             [-1, 64, 1, 1]               0
#             Conv2d-8              [-1, 4, 1, 1]             256
#               ReLU-9              [-1, 4, 1, 1]               0
#            Conv2d-10             [-1, 64, 1, 1]             256
# AdaptiveMaxPool2d-11             [-1, 64, 1, 1]               0
#            Conv2d-12              [-1, 4, 1, 1]             256
#              ReLU-13              [-1, 4, 1, 1]               0
#            Conv2d-14             [-1, 64, 1, 1]             256
#           Sigmoid-15             [-1, 64, 1, 1]               0
#  ChannelAttention-16             [-1, 64, 1, 1]               0
#            Conv2d-17          [-1, 1, 256, 256]              18
#           Sigmoid-18          [-1, 1, 256, 256]               0
#  SpatialAttention-19          [-1, 1, 256, 256]               0
#             PVDAB-20         [-1, 64, 256, 256]               0
#        BasicBlock-21         [-1, 64, 256, 256]               0
#            Conv2d-22         [-1, 64, 256, 256]          36,864
#       BatchNorm2d-23         [-1, 64, 256, 256]             128
#            Conv2d-24         [-1, 64, 256, 256]          36,864
#       BatchNorm2d-25         [-1, 64, 256, 256]             128
# AdaptiveAvgPool2d-26             [-1, 64, 1, 1]               0
#            Conv2d-27              [-1, 4, 1, 1]             256
#              ReLU-28              [-1, 4, 1, 1]               0
#            Conv2d-29             [-1, 64, 1, 1]             256
# AdaptiveMaxPool2d-30             [-1, 64, 1, 1]               0
#            Conv2d-31              [-1, 4, 1, 1]             256
#              ReLU-32              [-1, 4, 1, 1]               0
#            Conv2d-33             [-1, 64, 1, 1]             256
#           Sigmoid-34             [-1, 64, 1, 1]               0
#  ChannelAttention-35             [-1, 64, 1, 1]               0
#            Conv2d-36          [-1, 1, 256, 256]              18
#           Sigmoid-37          [-1, 1, 256, 256]               0
#  SpatialAttention-38          [-1, 1, 256, 256]               0
#             PVDAB-39         [-1, 64, 256, 256]               0
#        BasicBlock-40         [-1, 64, 256, 256]               0
#            Conv2d-41        [-1, 128, 128, 128]          73,728
#       BatchNorm2d-42        [-1, 128, 128, 128]             256
#            Conv2d-43        [-1, 128, 128, 128]         147,456
#       BatchNorm2d-44        [-1, 128, 128, 128]             256
# AdaptiveAvgPool2d-45            [-1, 128, 1, 1]               0
#            Conv2d-46              [-1, 8, 1, 1]           1,024
#              ReLU-47              [-1, 8, 1, 1]               0
#            Conv2d-48            [-1, 128, 1, 1]           1,024
# AdaptiveMaxPool2d-49            [-1, 128, 1, 1]               0
#            Conv2d-50              [-1, 8, 1, 1]           1,024
#              ReLU-51              [-1, 8, 1, 1]               0
#            Conv2d-52            [-1, 128, 1, 1]           1,024
#           Sigmoid-53            [-1, 128, 1, 1]               0
#  ChannelAttention-54            [-1, 128, 1, 1]               0
#            Conv2d-55          [-1, 1, 128, 128]              18
#           Sigmoid-56          [-1, 1, 128, 128]               0
#  SpatialAttention-57          [-1, 1, 128, 128]               0
#             PVDAB-58        [-1, 128, 128, 128]               0
#            Conv2d-59        [-1, 128, 128, 128]           8,192
#       BatchNorm2d-60        [-1, 128, 128, 128]             256
#        BasicBlock-61        [-1, 128, 128, 128]               0
#            Conv2d-62        [-1, 128, 128, 128]         147,456
#       BatchNorm2d-63        [-1, 128, 128, 128]             256
#            Conv2d-64        [-1, 128, 128, 128]         147,456
#       BatchNorm2d-65        [-1, 128, 128, 128]             256
# AdaptiveAvgPool2d-66            [-1, 128, 1, 1]               0
#            Conv2d-67              [-1, 8, 1, 1]           1,024
#              ReLU-68              [-1, 8, 1, 1]               0
#            Conv2d-69            [-1, 128, 1, 1]           1,024
# AdaptiveMaxPool2d-70            [-1, 128, 1, 1]               0
#            Conv2d-71              [-1, 8, 1, 1]           1,024
#              ReLU-72              [-1, 8, 1, 1]               0
#            Conv2d-73            [-1, 128, 1, 1]           1,024
#           Sigmoid-74            [-1, 128, 1, 1]               0
#  ChannelAttention-75            [-1, 128, 1, 1]               0
#            Conv2d-76          [-1, 1, 128, 128]              18
#           Sigmoid-77          [-1, 1, 128, 128]               0
#  SpatialAttention-78          [-1, 1, 128, 128]               0
#             PVDAB-79        [-1, 128, 128, 128]               0
#        BasicBlock-80        [-1, 128, 128, 128]               0
#            Conv2d-81          [-1, 256, 64, 64]         294,912
#       BatchNorm2d-82          [-1, 256, 64, 64]             512
#            Conv2d-83          [-1, 256, 64, 64]         589,824
#       BatchNorm2d-84          [-1, 256, 64, 64]             512
# AdaptiveAvgPool2d-85            [-1, 256, 1, 1]               0
#            Conv2d-86             [-1, 16, 1, 1]           4,096
#              ReLU-87             [-1, 16, 1, 1]               0
#            Conv2d-88            [-1, 256, 1, 1]           4,096
# AdaptiveMaxPool2d-89            [-1, 256, 1, 1]               0
#            Conv2d-90             [-1, 16, 1, 1]           4,096
#              ReLU-91             [-1, 16, 1, 1]               0
#            Conv2d-92            [-1, 256, 1, 1]           4,096
#           Sigmoid-93            [-1, 256, 1, 1]               0
#  ChannelAttention-94            [-1, 256, 1, 1]               0
#            Conv2d-95            [-1, 1, 64, 64]              18
#           Sigmoid-96            [-1, 1, 64, 64]               0
#  SpatialAttention-97            [-1, 1, 64, 64]               0
#             PVDAB-98          [-1, 256, 64, 64]               0
#            Conv2d-99          [-1, 256, 64, 64]          32,768
#      BatchNorm2d-100          [-1, 256, 64, 64]             512
#       BasicBlock-101          [-1, 256, 64, 64]               0
#           Conv2d-102          [-1, 256, 64, 64]         589,824
#      BatchNorm2d-103          [-1, 256, 64, 64]             512
#           Conv2d-104          [-1, 256, 64, 64]         589,824
#      BatchNorm2d-105          [-1, 256, 64, 64]             512
# AdaptiveAvgPool2d-106            [-1, 256, 1, 1]               0
#           Conv2d-107             [-1, 16, 1, 1]           4,096
#             ReLU-108             [-1, 16, 1, 1]               0
#           Conv2d-109            [-1, 256, 1, 1]           4,096
# AdaptiveMaxPool2d-110            [-1, 256, 1, 1]               0
#           Conv2d-111             [-1, 16, 1, 1]           4,096
#             ReLU-112             [-1, 16, 1, 1]               0
#           Conv2d-113            [-1, 256, 1, 1]           4,096
#          Sigmoid-114            [-1, 256, 1, 1]               0
# ChannelAttention-115            [-1, 256, 1, 1]               0
#           Conv2d-116            [-1, 1, 64, 64]              18
#          Sigmoid-117            [-1, 1, 64, 64]               0
# SpatialAttention-118            [-1, 1, 64, 64]               0
#            PVDAB-119          [-1, 256, 64, 64]               0
#       BasicBlock-120          [-1, 256, 64, 64]               0
#           Conv2d-121          [-1, 512, 32, 32]       1,179,648
#      BatchNorm2d-122          [-1, 512, 32, 32]           1,024
#           Conv2d-123          [-1, 512, 32, 32]       2,359,296
#      BatchNorm2d-124          [-1, 512, 32, 32]           1,024
# AdaptiveAvgPool2d-125            [-1, 512, 1, 1]               0
#           Conv2d-126             [-1, 32, 1, 1]          16,384
#             ReLU-127             [-1, 32, 1, 1]               0
#           Conv2d-128            [-1, 512, 1, 1]          16,384
# AdaptiveMaxPool2d-129            [-1, 512, 1, 1]               0
#           Conv2d-130             [-1, 32, 1, 1]          16,384
#             ReLU-131             [-1, 32, 1, 1]               0
#           Conv2d-132            [-1, 512, 1, 1]          16,384
#          Sigmoid-133            [-1, 512, 1, 1]               0
# ChannelAttention-134            [-1, 512, 1, 1]               0
#           Conv2d-135            [-1, 1, 32, 32]              18
#          Sigmoid-136            [-1, 1, 32, 32]               0
# SpatialAttention-137            [-1, 1, 32, 32]               0
#            PVDAB-138          [-1, 512, 32, 32]               0
#           Conv2d-139          [-1, 512, 32, 32]         131,072
#      BatchNorm2d-140          [-1, 512, 32, 32]           1,024
#       BasicBlock-141          [-1, 512, 32, 32]               0
#           Conv2d-142          [-1, 512, 32, 32]       2,359,296
#      BatchNorm2d-143          [-1, 512, 32, 32]           1,024
#           Conv2d-144          [-1, 512, 32, 32]       2,359,296
#      BatchNorm2d-145          [-1, 512, 32, 32]           1,024
# AdaptiveAvgPool2d-146            [-1, 512, 1, 1]               0
#           Conv2d-147             [-1, 32, 1, 1]          16,384
#             ReLU-148             [-1, 32, 1, 1]               0
#           Conv2d-149            [-1, 512, 1, 1]          16,384
# AdaptiveMaxPool2d-150            [-1, 512, 1, 1]               0
#           Conv2d-151             [-1, 32, 1, 1]          16,384
#             ReLU-152             [-1, 32, 1, 1]               0
#           Conv2d-153            [-1, 512, 1, 1]          16,384
#          Sigmoid-154            [-1, 512, 1, 1]               0
# ChannelAttention-155            [-1, 512, 1, 1]               0
#           Conv2d-156            [-1, 1, 32, 32]              18
#          Sigmoid-157            [-1, 1, 32, 32]               0
# SpatialAttention-158            [-1, 1, 32, 32]               0
#            PVDAB-159          [-1, 512, 32, 32]               0
#       BasicBlock-160          [-1, 512, 32, 32]               0
#           Linear-161                    [-1, 2]          65,538
# ================================================================
# Total params: 11,408,594
# Trainable params: 11,408,594
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.75
# Forward/backward pass size (MB): 844.08
# Params size (MB): 43.52
# Estimated Total Size (MB): 888.35
# ----------------------------------------------------------------

# %%
# loss function to be used
criterion = torch.nn.CrossEntropyLoss()
# optimizer to be used
optimizer = torch.optim.SGD(model.parameters(), lr=1e-4, momentum=0.9, weight_decay=5e-4)

# %%
# training process
from torch.utils.tensorboard import SummaryWriter
train_losses = 0.0
train_accuracy = 0
epochs = 40
for epoch in range(epochs):  # loop over the dataset multiple times
    print('Epoch-{0}:'.format(epoch + 1, optimizer.param_groups[0]['lr']))
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data # get the inputs; data is a list of [inputs, labels]
        inputs, labels = inputs.cuda(), labels.cuda() # for using data in GPU
        optimizer.zero_grad() # zero the parameter gradients
        outputs = model(inputs) # forward
        loss = criterion(outputs, labels) # calculate loss
        loss.backward() # backward loss
        optimizer.step() # optimize gradients
        train_losses += loss.item() # save loss
        _, preds = torch.max(outputs, 1) # save prediction
        train_accuracy += torch.sum(preds == labels.data) # save train_accuracy
        if i % 1000 == 999:    # every 1000 mini-batches...
            steps = epoch * len(trainloader) + i # calculate steps
            batch = i*batch_size # calculate batch
            print("Training loss {:.5} Training Accuracy {:.5} Steps: {}".format(train_losses / batch, train_accuracy/batch, steps))
            # Save train_accuracy and loss to Tensorboard
            writer.add_scalar('Training loss by steps', train_losses / batch, steps)
            writer.add_scalar('Training accuracy by steps', train_accuracy / batch, steps)
    print("Training Accuracy: {}/{} ({:.5} %) Training Loss: {:.5}".format(train_accuracy, len(trainloader), 100. * train_accuracy / len(trainloader.dataset), train_losses / len(trainloader.dataset)))
    train_losses = 0.0
    train_accuracy = 0
print('Train is finished...')

# %%
# validation process
from torch.utils.tensorboard import SummaryWriter
validation_losses = 0.0
validation_accuracy = 0
epochs = 40
for epoch in range(epochs):  # loop over the dataset multiple times
    print('Epoch-{0}:'.format(epoch + 1, optimizer.param_groups[0]['lr']))
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data # get the inputs; data is a list of [inputs, labels]
        inputs, labels = inputs.cuda(), labels.cuda() # for using data in GPU
        optimizer.zero_grad() # zero the parameter gradients
        outputs = model(inputs) # forward
        loss = criterion(outputs, labels) # calculate loss
        loss.backward() # backward loss
        optimizer.step() # optimize gradients
        validation_losses += loss.item() # save loss
        _, preds = torch.max(outputs, 1) # save prediction
        validation_accuracy += torch.sum(preds == labels.data) # save validation_accuracy
        if i % 1000 == 999:    # every 1000 mini-batches...
            steps = epoch * len(trainloader) + i # calculate steps
            batch = i*batch_size # calculate batch
            print("validation loss {:.5} validation accuracy {:.5} Steps: {}".format(validation_losses / batch, train_accuracy/batch, steps))
            # Save train_accuracy and loss to Tensorboard
            writer.add_scalar('validation loss by steps', validation_losses / batch, steps)
            writer.add_scalar('validation accuracy by steps', validation_accuracy / batch, steps)
    print("validation accuracy: {}/{} ({:.5} %) validation loss: {:.5}".format(validation_accuracy, len(validationloader), 100. * validation_accuracy / len(validationloader.dataset), validation_losses / len(validationloader.dataset)))
    validation_losses = 0.0
    validation_accuracy = 0
print('validation is finished...')

# %%
# test process
from torch.utils.tensorboard import SummaryWriter
test_losses = 0.0
test_accuracy = 0
epochs = 40
for epoch in range(epochs):  # loop over the dataset multiple times
    print('Epoch-{0}:'.format(epoch + 1, optimizer.param_groups[0]['lr']))
    for i, data in enumerate(testloader, 0):
        inputs, labels = data # get the inputs; data is a list of [inputs, labels]
        inputs, labels = inputs.cuda(), labels.cuda() # for using data in GPU
        optimizer.zero_grad() # zero the parameter gradients
        outputs = model(inputs) # forward
        loss = criterion(outputs, labels) # calculate loss
        loss.backward() # backward loss
        optimizer.step() # optimize gradients
        test_losses += loss.item() # save loss
        _, preds = torch.max(outputs, 1) # save prediction
        test_accuracy += torch.sum(preds == labels.data) # save test_accuracy
        if i % 1000 == 999:    # every 1000 mini-batches...
            steps = epoch * len(testloader) + i # calculate steps
            batch = i*batch_size # calculate batch
            print("Test loss {:.5} Test Accuracy {:.5} Steps: {}".format(test_losses / batch, test_accuracy/batch, steps))
            # Save test_accuracy and loss to Tensorboard
            writer.add_scalar('Test loss by steps', test_losses / batch, steps)
            writer.add_scalar('Test accuracy by steps', test_accuracy / batch, steps)
    print("Test Accuracy: {}/{} ({:.5} %) Test Loss: {:.5}".format(test_accuracy, len(testloader), 100. * test_accuracy / len(testloader.dataset), test_losses / len(testloader.dataset)))
    test_losses = 0.0
    test_accuracy = 0
print('Test is Finished...')

# %%
# import Times New Roman font
import matplotlib.font_manager
# !wget https://github.com/trishume/OpenTuringCompiler/blob/master/stdlib-sfml/fonts/Times%20New%20Roman.ttf -P /usr/local/lib/python3.6/dist-packages/matplotlib/mpl-data/fonts/ttf
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']
# plot test confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.metrics import ConfusionMatrixDisplay
import seaborn as sn
import pandas as pd
y_pred = []
y_true = []
# iterate over test data
for inputs, labels in testloader:
        inputs, labels = inputs.cuda(), labels.cuda()
        output = model(inputs) # Feed Network
        output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
        y_pred.extend(output) # Save Prediction
        labels = labels.data.cpu().numpy()
        y_true.extend(labels) # Save Truth
cm = confusion_matrix(y_true, y_pred)
cm_display = ConfusionMatrixDisplay(cm)
cm_display.plot(cmap=plt.cm.Greys)
plt.savefig('Test_confusion_matrix.jpeg')

# %%
# plot a healthy image from test set
import tensorflow
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
image = load_img('/content/OurALL-IDB2/content/dataset/train/healthy/Im137_0.tif')
data = img_to_array(image)
samples = np.expand_dims(data, 0)
print('Original healthy Image (Im137_0):')
plt.imshow(image)
plt.show()
# Out:
# Original healthy Image (Im137_0):

# %%
from torchvision import models, transforms, utils
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=0., std=1.)
])
# we will save the conv layer weights in this list
model_weights =[]
# we will save the 49 conv layers in this list
conv_layers = []
# get all the model children as list
model_children = list(model.children())
# counter to keep count of the conv layers
counter = 0
# append all the conv layers and their respective wights to the list
for i in range(len(model_children)):
    if type(model_children[i]) == nn.Conv2d:
        counter+=1
        model_weights.append(model_children[i].weight)
        conv_layers.append(model_children[i])
    elif type(model_children[i]) == nn.Sequential:
        for j in range(len(model_children[i])):
            for child in model_children[i][j].children():
                if type(child) == nn.Conv2d:
                    counter+=1
                    model_weights.append(child.weight)
                    conv_layers.append(child)
print(f"Total convolution layers: {counter}")
print("conv_layers")
# Out:
# Total convolution layers: 17
# conv_layers

# %%
from torch.autograd import Variable
import matplotlib.pyplot as plt
import scipy.misc
from PIL import Image
import json
# %matplotlib inline
image = transform(image)
print(f"Image shape before: {image.shape}")
image = image.unsqueeze(0)
print(f"Image shape after: {image.shape}")
image = image.to(device)
# Out:
# Image shape before: torch.Size([3, 256, 256])
# Image shape after: torch.Size([1, 3, 256, 256])

# %%
outputs = []
names = []
for layer in conv_layers[0:]:
    image = layer(image)
    outputs.append(image)
    names.append(str(layer))
print(len(outputs))
# print feature_maps
for feature_map in outputs:
    print(feature_map.shape)
# Out:
# 17
# torch.Size([1, 64, 256, 256])
# torch.Size([1, 64, 256, 256])
# torch.Size([1, 64, 256, 256])
# torch.Size([1, 64, 256, 256])
# torch.Size([1, 64, 256, 256])
# torch.Size([1, 128, 128, 128])
# torch.Size([1, 128, 128, 128])
# torch.Size([1, 128, 128, 128])
# torch.Size([1, 128, 128, 128])
# torch.Size([1, 256, 64, 64])
# torch.Size([1, 256, 64, 64])
# torch.Size([1, 256, 64, 64])
# torch.Size([1, 256, 64, 64])
# torch.Size([1, 512, 32, 32])
# torch.Size([1, 512, 32, 32])
# torch.Size([1, 512, 32, 32])
# torch.Size([1, 512, 32, 32])

# %%
processed = []
for feature_map in outputs:
    feature_map = feature_map.squeeze(0)
    gray_scale = torch.sum(feature_map,0)
    gray_scale = gray_scale / feature_map.shape[0]
    processed.append(gray_scale.data.cpu().numpy())
for fm in processed:
    print(fm.shape)
# Out:
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (128, 128)
# (128, 128)
# (128, 128)
# (128, 128)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)

# %%
# plot feature maps of the healthy image
fig = plt.figure(figsize=(30, 50))
for i in range(len(processed)):
    a = fig.add_subplot(5, 4, i+1)
    imgplot = plt.imshow(processed[i])
    a.axis("off")
    a.set_title(names[i].split('(')[0], fontsize=30)
plt.savefig(str('healthy feature_maps.jpg'), bbox_inches='tight')

# %%
# plot a blast image from test set
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
image = load_img('/content/OurALL-IDB2/content/dataset/train/blast/Im002_1.tif')
data = img_to_array(image)
samples = np.expand_dims(data, 0)
print('Original blast Image (Im002_1):')
plt.imshow(image)
plt.show()
# Out:
# Original blast Image (Im002_1):

# %%
from torchvision import models, transforms, utils
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=0., std=1.)
])

# %%
# we will save the conv layer weights in this list
model_weights =[]
# we will save the 49 conv layers in this list
conv_layers = []
# get all the model children as list
model_children = list(model.children())
# counter to keep count of the conv layers
counter = 0
# append all the conv layers and their respective wights to the list
for i in range(len(model_children)):
    if type(model_children[i]) == nn.Conv2d:
        counter+=1
        model_weights.append(model_children[i].weight)
        conv_layers.append(model_children[i])
    elif type(model_children[i]) == nn.Sequential:
        for j in range(len(model_children[i])):
            for child in model_children[i][j].children():
                if type(child) == nn.Conv2d:
                    counter+=1
                    model_weights.append(child.weight)
                    conv_layers.append(child)
print(f"Total convolution layers: {counter}")
print("conv_layers")
# Out:
# Total convolution layers: 17
# conv_layers

# %%
from torch.autograd import Variable
import matplotlib.pyplot as plt
import scipy.misc
from PIL import Image
import json
# %matplotlib inline
image = transform(image)
print(f"Image shape before: {image.shape}")
image = image.unsqueeze(0)
print(f"Image shape after: {image.shape}")
image = image.to(device)
# Out:
# Image shape before: torch.Size([3, 256, 256])
# Image shape after: torch.Size([1, 3, 256, 256])

# %%
outputs = []
names = []
for layer in conv_layers[0:]:
    image = layer(image)
    outputs.append(image)
    names.append(str(layer))
print(len(outputs))
# print feature_maps
for feature_map in outputs:
    print(feature_map.shape)
# Out:
# 17
# torch.Size([1, 64, 256, 256])
# torch.Size([1, 64, 256, 256])
# torch.Size([1, 64, 256, 256])
# torch.Size([1, 64, 256, 256])
# torch.Size([1, 64, 256, 256])
# torch.Size([1, 128, 128, 128])
# torch.Size([1, 128, 128, 128])
# torch.Size([1, 128, 128, 128])
# torch.Size([1, 128, 128, 128])
# torch.Size([1, 256, 64, 64])
# torch.Size([1, 256, 64, 64])
# torch.Size([1, 256, 64, 64])
# torch.Size([1, 256, 64, 64])
# torch.Size([1, 512, 32, 32])
# torch.Size([1, 512, 32, 32])
# torch.Size([1, 512, 32, 32])
# torch.Size([1, 512, 32, 32])

# %%
processed = []
for feature_map in outputs:
    feature_map = feature_map.squeeze(0)
    gray_scale = torch.sum(feature_map,0)
    gray_scale = gray_scale / feature_map.shape[0]
    processed.append(gray_scale.data.cpu().numpy())
for fm in processed:
    print(fm.shape)
# Out:
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (256, 256)
# (128, 128)
# (128, 128)
# (128, 128)
# (128, 128)
# (64, 64)
# (64, 64)
# (64, 64)
# (64, 64)
# (32, 32)
# (32, 32)
# (32, 32)
# (32, 32)

# %%
# plot feature maps of the blast image
fig = plt.figure(figsize=(30, 50))
for i in range(len(processed)):
    a = fig.add_subplot(5, 4, i+1)
    imgplot = plt.imshow(processed[i])
    a.axis("off")
    a.set_title(names[i].split('(')[0], fontsize=30)
plt.savefig(str('blast feature_maps.jpg'), bbox_inches='tight')

# %%
# !pip install git+https://github.com/jacobgil/pytorch-grad-cam.git
# Out:
# Collecting git+https://github.com/jacobgil/pytorch-grad-cam.git
#   Cloning https://github.com/jacobgil/pytorch-grad-cam.git to /tmp/pip-req-build-feirr36r
#   Running command git clone --filter=blob:none --quiet https://github.com/jacobgil/pytorch-grad-cam.git /tmp/pip-req-build-feirr36r
#   Resolved https://github.com/jacobgil/pytorch-grad-cam.git to commit af2d53ad6c80d075946dd99235e8591522b09b3f
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from grad-cam==1.4.8) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from grad-cam==1.4.8) (9.4.0)
# Requirement already satisfied: torch>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from grad-cam==1.4.8) (2.0.1+cu118)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.10/dist-packages (from grad-cam==1.4.8) (0.15.2+cu118)
# Collecting ttach (from grad-cam==1.4.8)
#   Downloading ttach-0.0.3-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from grad-cam==1.4.8) (4.66.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from grad-cam==1.4.8) (4.8.0.76)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from grad-cam==1.4.8) (3.7.1)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from grad-cam==1.4.8) (1.2.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam==1.4.8) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam==1.4.8) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam==1.4.8) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam==1.4.8) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam==1.4.8) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7.1->grad-cam==1.4.8) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7.1->grad-cam==1.4.8) (3.27.5)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.7.1->grad-cam==1.4.8) (17.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision>=0.8.2->grad-cam==1.4.8) (2.31.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam==1.4.8) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam==1.4.8) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam==1.4.8) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam==1.4.8) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam==1.4.8) (23.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam==1.4.8) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->grad-cam==1.4.8) (2.8.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->grad-cam==1.4.8) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->grad-cam==1.4.8) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->grad-cam==1.4.8) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->grad-cam==1.4.8) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7.1->grad-cam==1.4.8) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.8.2->grad-cam==1.4.8) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.8.2->grad-cam==1.4.8) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.8.2->grad-cam==1.4.8) (2.0.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision>=0.8.2->grad-cam==1.4.8) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.7.1->grad-cam==1.4.8) (1.3.0)
# Building wheels for collected packages: grad-cam
#   Building wheel for grad-cam (pyproject.toml) ... done
#   Created wheel for grad-cam: filename=grad_cam-1.4.8-py3-none-any.whl size=37441 sha256=bfd12f21c4f66efc49d9eede47874081ec4fd38f5fc64d241d0656b1ad6279ca
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ayqb_flw/wheels/23/11/66/71a38b0c29ba4ec5f62105a2145278613855bc9c94eecf630d
# Successfully built grad-cam
# Installing collected packages: ttach, grad-cam
# Successfully installed grad-cam-1.4.8 ttach-0.0.3

# %%
import copy
from pytorch_grad_cam import GradCAM, ScoreCAM, GradCAMPlusPlus, AblationCAM, XGradCAM, EigenCAM, FullGrad
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
from pytorch_grad_cam.utils.image import show_cam_on_image
from torchvision.models import resnet18
import numpy as np
from PIL import Image
import torch
import torch.nn as nn
import torchvision

# %%
# Pick up layers for visualization
target_layers = [model.layer4[-1]]

# %%
path1 = ('/content/OurALL-IDB2/content/dataset/train/healthy/Im137_0.tif')
print('original healthy cell:')
Image.open(path1).convert('RGB')
# Out:
# original healthy cell:
# <PIL.Image.Image image mode=RGB size=257x257>

# %%
rgb_img = Image.open(path1).convert('RGB')
# Max min normalization
rgb_img = (rgb_img - np.min(rgb_img)) / (np.max(rgb_img) - np.min(rgb_img))
# Create an input tensor image for your model
input_tensor = torchvision.transforms.functional.to_tensor(rgb_img).unsqueeze(0).float()
# Note: input_tensor can be a batch tensor with several images!
# Construct the CAM object once, and then re-use it on many images:
cam = GradCAM(model=model, target_layers=target_layers, use_cuda=True)
# cam = GradCAMPlusPlus(model=model, target_layers=target_layers, use_cuda=False)
# cam = ScoreCAM(model=model, target_layers=target_layers, use_cuda=False)
# You can also use it within a with statement, to make sure it is freed,
# In case you need to re-create it inside an outer loop:
# with GradCAM(model=model, target_layers=target_layers, use_cuda=args.use_cuda) as cam:
#   ...
# We have to specify the target we want to generate
# the Class Activation Maps for.
# If targets is None, the highest scoring category
# will be used for every image in the batch.
# Here we use ClassifierOutputTarget, but you can define your own custom targets
# That are, for example, combinations of categories, or specific outputs in a non standard model.
# targets = [e.g ClassifierOutputTarget(281)]
# target_category = None
# You can also pass aug_smooth=True and eigen_smooth=True, to apply smoothing.
grayscale_cam = cam(input_tensor=input_tensor)
# In this example grayscale_cam has only one image in the batch:
grayscale_cam = grayscale_cam[0, :]
visualization = show_cam_on_image(rgb_img, grayscale_cam, use_rgb=True)

# %%
# plot healthy cell GradCAM
print('healthy cell GradCAM:')
Image.fromarray(visualization, 'RGB')

# %%
rgb_img = Image.open(path1).convert('RGB')
# Max min normalization
rgb_img = (rgb_img - np.min(rgb_img)) / (np.max(rgb_img) - np.min(rgb_img))
# Create an input tensor image for your model
input_tensor = torchvision.transforms.functional.to_tensor(rgb_img).unsqueeze(0).float()
# Note: input_tensor can be a batch tensor with several images!
# Construct the CAM object once, and then re-use it on many images:
#cam = GradCAM(model=model, target_layers=target_layers, use_cuda=True)
cam = GradCAMPlusPlus(model=model, target_layers=target_layers, use_cuda=True)
# cam = ScoreCAM(model=model, target_layers=target_layers, use_cuda=False)
# You can also use it within a with statement, to make sure it is freed,
# In case you need to re-create it inside an outer loop:
# with GradCAM(model=model, target_layers=target_layers, use_cuda=args.use_cuda) as cam:
#   ...
# We have to specify the target we want to generate
# the Class Activation Maps for.
# If targets is None, the highest scoring category
# will be used for every image in the batch.
# Here we use ClassifierOutputTarget, but you can define your own custom targets
# That are, for example, combinations of categories, or specific outputs in a non standard model.
# targets = [e.g ClassifierOutputTarget(281)]
# target_category = None
# You can also pass aug_smooth=True and eigen_smooth=True, to apply smoothing.
grayscale_cam = cam(input_tensor=input_tensor)
# In this example grayscale_cam has only one image in the batch:
grayscale_cam = grayscale_cam[0, :]
visualization = show_cam_on_image(rgb_img, grayscale_cam, use_rgb=True)

# %%
# plot healthy cell GradCAMPlusPlus
print('healthy cell GradCAMPlusPlus')
Image.fromarray(visualization, 'RGB')

# %%
rgb_img = Image.open(path1).convert('RGB')
# Max min normalization
rgb_img = (rgb_img - np.min(rgb_img)) / (np.max(rgb_img) - np.min(rgb_img))
# Create an input tensor image for your model
input_tensor = torchvision.transforms.functional.to_tensor(rgb_img).unsqueeze(0).float()
# Note: input_tensor can be a batch tensor with several images!
# Construct the CAM object once, and then re-use it on many images:
#cam = GradCAM(model=model, target_layers=target_layers, use_cuda=True)
#cam = GradCAMPlusPlus(model=model, target_layers=target_layers, use_cuda=True)
cam = ScoreCAM(model=model, target_layers=target_layers, use_cuda=True)
# You can also use it within a with statement, to make sure it is freed,
# In case you need to re-create it inside an outer loop:
# with GradCAM(model=model, target_layers=target_layers, use_cuda=args.use_cuda) as cam:
#   ...
# We have to specify the target we want to generate
# the Class Activation Maps for.
# If targets is None, the highest scoring category
# will be used for every image in the batch.
# Here we use ClassifierOutputTarget, but you can define your own custom targets
# That are, for example, combinations of categories, or specific outputs in a non standard model.
# targets = [e.g ClassifierOutputTarget(281)]
# target_category = None
# You can also pass aug_smooth=True and eigen_smooth=True, to apply smoothing.
grayscale_cam = cam(input_tensor=input_tensor)
# In this example grayscale_cam has only one image in the batch:
grayscale_cam = grayscale_cam[0, :]
visualization = show_cam_on_image(rgb_img, grayscale_cam, use_rgb=True)

# %%
# plot healthy cell ScoreCAM
print('healthy cell ScoreCAM:')
Image.fromarray(visualization, 'RGB')

# %%
path2 = ('/content/OurALL-IDB2/content/dataset/train/blast/Im002_1.tif')
print('original leukemia cell:')
Image.open(path2).convert('RGB')
# Out:
# original leukemia cell:
# <PIL.Image.Image image mode=RGB size=257x257>

# %%
rgb_img = Image.open(path2).convert('RGB')
# Max min normalization
rgb_img = (rgb_img - np.min(rgb_img)) / (np.max(rgb_img) - np.min(rgb_img))
# Create an input tensor image for your model
input_tensor = torchvision.transforms.functional.to_tensor(rgb_img).unsqueeze(0).float()
# Note: input_tensor can be a batch tensor with several images!

# Construct the CAM object once, and then re-use it on many images:
cam1 = GradCAM(model=model, target_layers=target_layers, use_cuda=True)
#cam = GradCAMPlusPlus(model=model, target_layers=target_layers, use_cuda=True)
# cam = ScoreCAM(model=model, target_layers=target_layers, use_cuda=False)

# You can also use it within a with statement, to make sure it is freed,
# In case you need to re-create it inside an outer loop:
# with GradCAM(model=model, target_layers=target_layers, use_cuda=args.use_cuda) as cam:
#   ...

# We have to specify the target we want to generate
# the Class Activation Maps for.
# If targets is None, the highest scoring category
# will be used for every image in the batch.
# Here we use ClassifierOutputTarget, but you can define your own custom targets
# That are, for example, combinations of categories, or specific outputs in a non standard model.
# targets = [e.g ClassifierOutputTarget(281)]
# target_category = None

# You can also pass aug_smooth=True and eigen_smooth=True, to apply smoothing.
grayscale_cam1 = cam1(input_tensor=input_tensor)

# In this example grayscale_cam1 has only one image in the batch:
grayscale_cam1 = grayscale_cam1[0, :]
visualization = show_cam_on_image(rgb_img, grayscale_cam1, use_rgb=True)

# %%
# plot leukemia cell GradCAM
print('leukemia cell GradCAM:')
Image.fromarray(visualization, 'RGB')

# %%
rgb_img = Image.open(path2).convert('RGB')
# Max min normalization
rgb_img = (rgb_img - np.min(rgb_img)) / (np.max(rgb_img) - np.min(rgb_img))
# Create an input tensor image for your model
input_tensor = torchvision.transforms.functional.to_tensor(rgb_img).unsqueeze(0).float()
# Note: input_tensor can be a batch tensor with several images!
# Construct the CAM object once, and then re-use it on many images:
#cam = GradCAM(model=model, target_layers=target_layers, use_cuda=True)
cam = GradCAMPlusPlus(model=model, target_layers=target_layers, use_cuda=True)
# cam = ScoreCAM(model=model, target_layers=target_layers, use_cuda=False)
# You can also use it within a with statement, to make sure it is freed,
# In case you need to re-create it inside an outer loop:
# with GradCAM(model=model, target_layers=target_layers, use_cuda=args.use_cuda) as cam:
#   ...
# We have to specify the target we want to generate
# the Class Activation Maps for.
# If targets is None, the highest scoring category
# will be used for every image in the batch.
# Here we use ClassifierOutputTarget, but you can define your own custom targets
# That are, for example, combinations of categories, or specific outputs in a non standard model.
# targets = [e.g ClassifierOutputTarget(281)]
# target_category = None
# You can also pass aug_smooth=True and eigen_smooth=True, to apply smoothing.
grayscale_cam = cam(input_tensor=input_tensor)
# In this example grayscale_cam has only one image in the batch:
grayscale_cam = grayscale_cam[0, :]
visualization = show_cam_on_image(rgb_img, grayscale_cam, use_rgb=True)

# %%
# plot leukemia cell GradCAMPlusPlus
print('leukemia cell GradCAMPlusPlus')
Image.fromarray(visualization, 'RGB')

# %%
rgb_img = Image.open(path2).convert('RGB')
# Max min normalization
rgb_img = (rgb_img - np.min(rgb_img)) / (np.max(rgb_img) - np.min(rgb_img))
# Create an input tensor image for your model
input_tensor = torchvision.transforms.functional.to_tensor(rgb_img).unsqueeze(0).float()
# Note: input_tensor can be a batch tensor with several images!
# Construct the CAM object once, and then re-use it on many images:
#cam = GradCAM(model=model, target_layers=target_layers, use_cuda=True)
#cam = GradCAMPlusPlus(model=model, target_layers=target_layers, use_cuda=True)
cam = ScoreCAM(model=model, target_layers=target_layers, use_cuda=True)
# You can also use it within a with statement, to make sure it is freed,
# In case you need to re-create it inside an outer loop:
# with GradCAM(model=model, target_layers=target_layers, use_cuda=args.use_cuda) as cam:
#   ...
# We have to specify the target we want to generate
# the Class Activation Maps for.
# If targets is None, the highest scoring category
# will be used for every image in the batch.
# Here we use ClassifierOutputTarget, but you can define your own custom targets
# That are, for example, combinations of categories, or specific outputs in a non standard model.
# targets = [e.g ClassifierOutputTarget(281)]
# target_category = None
# You can also pass aug_smooth=True and eigen_smooth=True, to apply smoothing.
grayscale_cam = cam(input_tensor=input_tensor)
# In this example grayscale_cam has only one image in the batch:
grayscale_cam = grayscale_cam[0, :]
visualization = show_cam_on_image(rgb_img, grayscale_cam, use_rgb=True)

# %%
# plot leukemia cell ScoreCAM
print('leukemia cell ScoreCAM:')
Image.fromarray(visualization, 'RGB')
